# %%
import datetime
import math

# %%
#Faça um programa que lê um número inteiro 𝑛 e imprime a mensagem:
#“O numero eh par” (caso 𝑛 seja par)
#“O numero eh impar” (caso 𝑛 seja ímpar)

n = int(input('escreva um número: '))
resto = n % 2
if resto == 0:
  print('O número', n,'é par')
else:
  print('O número', n,'é impar')
# Out:
# escreva um número: 3
# O número 3 é impar

# %%
#Escreva um programa que solicite ao usuário uma letra MAIÚSCULA e verifique se ela é uma vogal ou não, exibindo uma mensagem correspondente. Exiba:
#Caso verdadeiro: “Eh uma vogal”
#Caso falso: “Nao eh uma vogal”
letra = input('escreva um número: ')
vogais = 'aeiou'

if letra in vogais or letra in vogais.upper():
  print(letra, 'é uma vogal')
else:
   print(letra, 'é uma consoante')
# Out:
# escreva um número: a
# a é uma vogal

# %%
#Leia 4 valores inteiros, fornecidos pelo usuário na linha de comando, A, B, C e D. A seguir, se todas as três condições abaixo são verdadeiras,
#escreva a mensagem "Valores aceitos", senão escreva "Valores nao aceitos":
#i. B maior do que C
#ii. D maior do que A
#iii. a soma de C com D maior que a soma de A com B

A = int(input('escreva um número: '))
B = int(input('escreva um número: '))
C = int(input('escreva um número: '))
D = int(input('escreva um número: '))

if B>C and D>A and C+D>A+B:
    print('Valores Aceitos')
else:
  print('Valores não aceitos')

# %%
#Escreva um programa que calcule a idade de uma pessoa a partir do seu ano de nascimento.
#O programa deve mostrar na tela a idade e também as seguintes mensagens, quando for o caso:
#"Ja pode votar" (se tiver 16 anos ou mais)
#"Ja pode solicitar a Carteira de Habilitacao" (se tiver 18 anos ou mais)

nascimento = int(input('escreva o ano de nascimento: '))
currentDateTime = datetime.datetime.now()
date = currentDateTime.date()
ano_atual = int(date.strftime("%Y"))
idade = ano_atual - nascimento
print(idade) 

if idade>=16:
  print("Ja pode votar")
elif idade>=18:
    print("Ja pode solicitar a Carteira de Habilitacao")
else:
  print("Não pode votar")

# %%
#Escreva um algoritmo que peça como entrada os coeficientes a, b e c (números reais) de uma equação de 2.o grau.
#Suponha que o usuário sempre digita um número positivo para o coeficiente a. O programa deve fornecer como saída:
#I. se Δ = 0 : Calcule e imprime a única raiz pela fórmula de Bhaskara
#II. se Δ < 0 : Imprima a mensagem: "As duas raizes sao complexas"
#III. se Δ > 0 : Calcule e imprime as 2 raízes reais (com duas casas decimais) pela fórmula de Bhaskara (Δ=𝑏2−4𝑎𝑐)

a = int(input('escreva um número: '))
b = int(input('escreva um número: '))
c = int(input('escreva um número: '))

delta = (b**2 - 4*a*c)

raiz_1 = (-b + (delta**1/2)/2*a)

raiz_2 = (-b - (delta**1/2)/2*a)

if delta == 0:
  print((-b+((delta**1/2)))/2*a)

if delta > 0:
  print('As duas raizes são complexas')

if delta < 0:
  print('\nAs duas raizes são %2.f e %2.f'%(raiz_1, raiz_2))
# Out:
# escreva um número: 5
# escreva um número: 3
# escreva um número: 6
#
# As duas raizes são -142 e 136

# %%
#Escreva um algoritmo que peça como entrada o peso (em kilogramas- número inteiro) e a altura (em metros-número com duas casas decimais) da pessoa.
#O programa deve calcular e exibir o seu IMC – Índice de Massa Corpórea. Adicionalmente, o programa deve emitir a mensagem

peso = float(input('peso em kg: '))
altura = float(input('altura em m: '))
imc = peso / (altura**2)
print(imc)
if imc<18.5:
  print('Você está abaixo do peso ideal')
elif 18.5 <= imc < 24.9:
   print('Parabéns, você está no peso normal !')
elif 24.0 <= imc < 29.9:
   print('Voce está acima do peso (sobrepeso)')
elif 30.0 <= imc < 34.9:
   print('Obesidade Grau I')
elif 35.0 <= imc < 39.9:
   print('Obesidade Grau II')
elif imc >= 40.0:
   print('Obesidade Grau III')
