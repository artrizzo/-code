# %%
import pandas as pd

# %%
tabela_futebol = pd.read_csv('https://drive.google.com/u/3/uc?id=1iBP9J-RdN4D8f-eZKp1KDK6Y_dqOH5J9&export=download', sep = ",")

# %%
display(tabela_futebol.head(5))

# %%
display(tabela_futebol.tail(8))

# %%
colunas = ['Stadium', 'Country', 'Population']
display(tabela_futebol[colunas].head(10))

# %%
coluna_hometeams = ['HomeTeams']
display(tabela_futebol[coluna_hometeams])
