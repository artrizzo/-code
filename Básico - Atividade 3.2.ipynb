# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://drive.google.com/u/1/uc?id=182_Z-bL7n9itkupECYhIOEGuIjfQbF0Z&export=download')

# %%
df

# %%
# calculando a média e a mediana
print('Media: ', df['temperatura'].mean())
print('Mediana: ', df['temperatura'].median())

# %%
# calculando os percentis: 25
np.percentile(df, q=25)

# %%
# calculando os pertencis: 55
np.percentile(df, q=55)

# %%
# calculando os pertencis: 75
np.percentile(df, q=75)

# %%
# calculando as modas de temperatura
df['temperatura'].mode()
# Out:
# 0    15
# 1    17
# dtype: int64

# %%
#Escreva instruções para ler o nome de uma coluna da tabela (período ou temperatura), obter e imprimir a(s) moda(s) no conjunto de dados da coluna lida.

coluna = input()

df[coluna].mode()

# %%
# Crie a nova coluna com nome "razao" para qual o valor para cada período é a temperatura dividida pelo período.
# Imprime a tabela com esta nova coluna. 

df['razao'] = df.temperatura / df.periodo
df

# %%
# Calcule a variância de valores na coluna "razao"
df['razao'].var()

# %%
# Calcule a(s) moda(s) de temperatura. Calcule e imprima a menor moda.
min(df['temperatura'].mode())
